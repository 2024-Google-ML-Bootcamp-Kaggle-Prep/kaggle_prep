# %% [markdown]
# # Pycaret sample

# %% [markdown]
# ## load data

# %%
from pycaret.datasets import get_data
dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
train = dataset.sample(frac=0.95, random_state=786)
test = dataset.drop(train.index)
train.reset_index(inplace=True, drop=True)
test.reset_index(inplace=True, drop=True)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.4.2'

# %%
import scipy
scipy.__version__
# Out:
# '1.11.4'

# %%
import pyarrow

pyarrow.__version__
# Out:
# '16.1.0'

# %% [markdown]
# ## Configure data

# %%
from pycaret.classification import *

exp_clf = setup(data = train, target = 'default', session_id=123, use_gpu = True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 from pycaret.classification import *
# ----> 3 exp_clf = setup(data = train, target = 'default', session_id=123, use_gpu = True)
#
# ...

# %% [markdown]
# ## compare models

# %%
best_model = compare_models(include = ['lr', 'knn', 'nb', 'dt', 'svm', 'rbfsvm', 
                                       'gpc', 'mlp', 'ridge', 'rf', 'qda', 'ada', 
                                       'gbc', 'lda', 'et', 'xgboost', 'dummy'])
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     11:47:28
# Status     . . . . . . . . . . . . . . . . . .             Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gaussian Process Classifier
# <style type="text/css">
# #T_f7495 th {
#   text-align: left;
# }
# ...

# %%
best_model = compare_models(exclude = ['xgboost'])
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:42:35
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 best_model = compare_models(exclude = ['xgboost'])
#
# File ~/anaconda3/envs/kaggle/lib/python3.11/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# ...

# %%
models()
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# ...
